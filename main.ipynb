# %%
from myimage.image_helper import ImageHelper
import pytesseract

# %%
image_path = "images/dutchid_front.jpg"
image_helper = ImageHelper()

# %%
image = image_helper.load_image(image_path, is_greyscale=False)

# %%
prin

# %%
rgb_image = image_helper.convert_image_to_rgb(image)

# %%
image_helper.plot_image(rgb_image,heigh=8, width=4, title="Original Image")

# %%
grey_image = image_helper.convert_image_to_greyscale(image)

# %%
treshold_image = image_helper.thesholding(grey_image)

# %%
remove_noise_image = image_helper.remove_noise(treshold_image)

# %%
print(pytesseract.image_to_string(remove_noise_image))
# Out:
# Re-terenag 4 geese
#
# SPECIMEN
#
# De Bruijn
#
# tamer ques came
#
# willeke Liselotte
#
# viF Nederlandse
#
# eben ee
#
# rl 0 MAA/MAR 1965
#
# deem vee
#
# 02 AUG/AUG 202 1
#
# fe-agror ee
#
# 02 AUG/AUG 2031
# 123456
#
# SPECI2021 ~
#
# tee
# aoe:
# oe

# %%
crop = image_helper.image_crop(image, 50, 500, 50, 500)

# %%
image[0:450, 0:450] = crop
image_helper.show_image(image)
# Out:
# 2025-03-15 03:18:08.968 Python[2596:99763] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-03-15 03:18:08.968 Python[2596:99763] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %%
image_helper.get_type(image)
# Out:
# dtype('uint8')

# %%
canva = image_helper.create_canvas(100, 200, 3)

# %%
canva = image_helper.update_image_color(canva, 'r', 255)

# %%
canva[:, :, 2] = 255

# %%
image_helper.show_image(canva)
# Out:
# 2025-03-15 03:04:30.643 Python[2517:93858] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-03-15 03:04:30.643 Python[2517:93858] +[IMKInputSession subclass]: chose IMKInputSession_Modern
